# %% [markdown]
# # Breast Cancer Recurrence Prediction Model
# ## A Step-by-Step Machine Learning Approach
# ---
# This notebook presents a complete machine learning pipeline for predicting breast cancer recurrence.

# %% [markdown]
# ## 1. Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8-whitegrid')
print("All libraries imported!")

# %% [markdown]
# ## 2. Loading the Dataset

# %%
df = pd.read_csv('data/breast_cancer.csv')
print(f'Dataset Shape: {df.shape}')

# %% [markdown]
# ## 3. Exploratory Data Analysis
# ### 3.1 Display First Rows

# %%
df.head(10)

# %% [markdown]
# ### 3.2 Data Types

# %%
df.info()

# %% [markdown]
# ### 3.3 Describe

# %%
df.describe()

# %% [markdown]
# ### 3.4 Missing Values

# %%
print("Missing values:")
print(df.isnull().sum())

# %% [markdown]
# ### 3.5 Target Distribution

# %%
print("Target distribution:")
print(df["class"].value_counts())

# %% [markdown]
# ### 3.6 Class Distribution Visualization

# %%
plt.figure(figsize=(8,5))
df["class"].value_counts().plot(kind="bar", color=["green","red"])
plt.title("Class Distribution")
plt.xlabel("Class (0=No Recurrence, 1=Recurrence)")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## 4. Data Preprocessing
# ### 4.1 Target Encoding

# %%
print("Target is already encoded: 0=No Recurrence, 1=Recurrence")
print(df["class"].unique())

# %% [markdown]
# ### 4.2 Feature Identification

# %%
X = df.drop("class", axis=1)
y = df["class"]
categorical_cols = X.select_dtypes(include=["object"]).columns.tolist()
print(f"Categorical features: {categorical_cols}")

# %% [markdown]
# ### 4.3 One-Hot Encoding

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), categorical_cols)
    ]
)
X_encoded = preprocessor.fit_transform(X)
print(f"Features before: {X.shape[1]}, after encoding: {X_encoded.shape[1]}")

# %% [markdown]
# ### 4.4 Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, stratify=y, random_state=42
)
print(f"Train: {X_train.shape[0]}, Test: {X_test.shape[0]}")

# %% [markdown]
# ## 5. Model Development
# ### 5.1 Model Selection

# %%
model = LogisticRegression(max_iter=1000, class_weight="balanced", random_state=42)
print("Logistic Regression with balanced class weights selected")

# %% [markdown]
# ### 5.2 Model Training

# %%
model.fit(X_train, y_train)
print(f"Training accuracy: {model.score(X_train, y_train):.4f}")

# %% [markdown]
# ## 6. Model Evaluation
# ### 6.1 Predictions

# %%
y_pred = model.predict(X_test)
print(f"Predictions generated for {len(y_pred)} samples")

# %% [markdown]
# ### 6.2 Evaluation Metrics

# %%
accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)
print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")

# %% [markdown]
# ### 6.3 Confusion Matrix

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["No Recurrence", "Recurrence"],
            yticklabels=["No Recurrence", "Recurrence"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ### 6.4 Classification Report

# %%
print(classification_report(y_test, y_pred, target_names=["No Recurrence", "Recurrence"]))

# %% [markdown]
# ## 7. Results Interpretation
# **Accuracy:** Overall correctness of predictions
# **Sensitivity (Recall):** Ability to detect recurrence cases (critical for medical diagnosis)
# **Specificity:** Ability to correctly identify non-recurrence cases
#
# The model achieves good sensitivity which is crucial for medical screening applications.

# %% [markdown]
# ## 8. Conclusion
# This notebook demonstrates a complete ML pipeline for breast cancer recurrence prediction using Logistic Regression with balanced class weights to handle the imbalanced dataset.
